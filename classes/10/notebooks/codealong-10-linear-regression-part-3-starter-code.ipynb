# %% [markdown]
# # DS-SF-36 | 10 | Linear Regression, Part 3 | Codealong | Starter Code

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import seaborn as sns
# Out:
# C:\Users\liz38\AppData\Local\Continuum\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Part A | Model Fit and Customer Retention

# %%
# TODO
train_df = pd.DataFrame({'t': range(8),
       'survival_rate': [1., .869, .743, .653, .593, .551, .517, .491]},
   columns = ['t', 'survival_rate'])

# %%
def Xy(df):
    X = df['t'] # X is a DataFrame
    X = sm.add_constant(X)
    y = df['survival_rate'] # y is a Series
    return X, y
X, y = Xy(train_df)
model = smf.OLS(y, X).fit()
model.summary()
import matplotlib.pyplot as plt
plt.plot(train_df['t'],train_df['survival_rate'])
plt.plot(predict_X['t'],predict_y)
plt.legend(['real', 'predict'], loc='upper left')
plt.show()

# %%
import math
def Xy(df):
    X = df['t'] # X is a DataFrame
    X = sm.add_constant(X)
    y = df['survival_rate'].apply(lambda x: math.log(x)) # y is a Series
    return X, y
X, y = Xy(train_df)
model = smf.OLS(y, X).fit()
model.summary()
predict_X = pd.DataFrame({'t':[9,10,11,12]})
predict_X = sm.add_constant(predict_X)
predict_y = model.predict(predict_X)
predict_y.apply(lambda x: math.exp(x))
import matplotlib.pyplot as plt
plt.plot(train_df['t'],train_df['survival_rate'])
plt.plot(predict_X['t'],predict_y.apply(lambda x: math.exp(x)))
plt.legend(['real', 'predict'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(train_df['t'],train_df['survival_rate'])
plt.plot(predict_X['t'],predict_y.apply(lambda x: math.exp(x)))
plt.legend(['real', 'predict'], loc='upper left')
plt.show()
# Out:
# 2.302585092994046

# %%
math.exp(2.302585092994046)
# Out:
# 10.000000000000002

# %%
predict_X
# Out:
#     const   t
# 0     1.0   0
# 1     1.0   1
# 2     1.0   2
# 3     1.0   3
# 4     1.0   4
# 5     1.0   5
# 6     1.0   6
# 7     1.0   7
# 8     1.0   8
# 9     1.0   9
# 10    1.0  10
# 11    1.0  11

# %% [markdown]
# ## Part B | One-Hot Encoding for Categorical Variables and SF Housing

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-10-zillow.csv'), index_col = 'ID')

# %%
df.drop(df[df.IsAStudio == 1].index, inplace = True)

# %%
smf.ols(formula = 'SalePrice ~ Baths', data = df).fit().summary()

# %% [markdown]
# > ### What's the bathrooms' distribution in the dataset?

# %%
# TODO

# %% [markdown]
# > ### Let's keep properties with 1, 2, 3, or 4 bathrooms

# %%
# TODO

# %% [markdown]
# > ### Let's use `pandas`'s `get_dummies` to create a one-hot encoding of the `Bath` categorical feature

# %%
# TODO

# %%
baths_df

# %%
baths_df.rename(columns = {'Bath_1.0': 'Bath_1',
    'Bath_2.0': 'Bath_2',
    'Bath_3.0': 'Bath_3',
    'Bath_4.0': 'Bath_4'}, inplace = True)

# %%
baths_df

# %%
df = df.join([baths_df])

# %%
df.columns

# %% [markdown]
# ### Activity | Linear modeling using `Bath`'s one-hot encoding

# %% [markdown]
# > ### `SalesPrice` as a function of `Bath_2`, `Bath_3`, and `Bath_4`

# %%
# TODO

# %% [markdown]
# > ### `SalesPrice` as a function of `Bath_1`, `Bath_3`, and `Bath_4`

# %%
# TODO

# %% [markdown]
# > ### `SalesPrice` as a function of `Bath_1`, `Bath_2`, and `Bath_4`

# %%
# TODO

# %% [markdown]
# > ### `SalesPrice` as a function of `Bath_1`, `Bath_2`, and `Bath_3`

# %%
# TODO

# %% [markdown]
# ## Part C | The Adverstising Dataset

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-10-advertising.csv'))

# %%
df

# %% [markdown]
# ### Plots

# %% [markdown]
# > ### Sales ~ TV

# %%
sns.lmplot(x = 'TV', y = 'Sales', data = df)

# %% [markdown]
# > ### Sales ~ Radio

# %%
sns.lmplot(x = 'Radio', y = 'Sales', data = df)

# %% [markdown]
# > ### Sales ~ Newspaper

# %%
sns.lmplot(x = 'Newspaper', y = 'Sales', data = df)

# %% [markdown]
# ### Simple linear regressions

# %% [markdown]
# > ### Sales ~ TV

# %%
model_tv = smf.ols(formula = 'Sales ~ TV', data = df).fit()

model_tv.summary()

# %% [markdown]
# > ### Sales ~ Radio

# %%
model_radio = smf.ols(formula = 'Sales ~ Radio', data = df).fit()

model_radio.summary()

# %% [markdown]
# > ### Sales ~ Newspaper

# %%
model_newspaper = smf.ols(formula = 'Sales ~ Newspaper', data = df).fit()

model_newspaper.summary()

# %% [markdown]
# ### Residuals

# %% [markdown]
# > ### Sales ~ TV

# %%
sm.qqplot(model_tv.resid, line = 's')

pass

# %%
sm.graphics.plot_regress_exog(model_tv, 'TV')

pass

# %% [markdown]
# > ### Sales ~ Radio

# %%
sm.qqplot(model_radio.resid, line = 's')

pass

# %%
sm.graphics.plot_regress_exog(model_radio, 'Radio')

pass

# %% [markdown]
# > ### Sales ~ Newspaper

# %%
sm.qqplot(model_newspaper.resid, line = 's')

pass

# %%
sm.graphics.plot_regress_exog(model_newspaper, 'Newspaper')

pass

# %% [markdown]
# > ### Sales ~ TV + Radio + Newspaper

# %%
# TODO

model.summary()

# %% [markdown]
# > ### Sales ~ TV + Radio

# %%
# TODO

model.summary()

# %%
sm.qqplot(model.resid, line = 's')

pass

# %%
sm.graphics.plot_regress_exog(model, 'TV')

pass

# %%
sm.graphics.plot_regress_exog(model, 'Radio')

pass

# %% [markdown]
# ## Part D | Interaction Effects and Advertising

# %% [markdown]
# ### Sales ~ TV + Radio + TV * Radio

# %%
model = smf.ols(formula = 'Sales ~ TV + Radio + TV * Radio', data = df).fit()

model.summary()

# %%
sm.qqplot(model.resid, line = 's')

pass

# %%
sm.graphics.plot_regress_exog(model, 'TV')

pass

# %%
sm.graphics.plot_regress_exog(model, 'Radio')

pass

# %%
sm.graphics.plot_regress_exog(model, 'TV:Radio')

pass
